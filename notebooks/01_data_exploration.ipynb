# %%
import pandas as pd
import numpy as np

file_path = "../data/raw/Electric_Vehicle_Population_Data.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# ...

# %%
df.info()
df.describe(include='all').T
df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112634 entries, 0 to 112633
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         112634 non-null  object
#  1   County                                             112634 non-null  object
#  2   City                                               112634 non-null  object
#  3   State                                              112634 non-null  object
#  4   Postal Code                                        112634 non-null  int64
#  5   Model Year                                         112634 non-null  int64
#  6   Make                                               112634 non-null  object
#  7   Model                                              112614 non-null  object
# ...

# %%
import sys
import os

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now import your module
from src.visual_style import apply_visual_style

apply_visual_style()
# Out:
# ✅ Applied 'vibrant_tech' style with colors ['#00B8A9', '#F6416C', '#FFDE7D', '#6A2C70', '#355C7D']

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.visual_style import randomize_palette, apply_visual_style

# Option 1 — random beautiful style
randomize_palette()

# Option 2 — apply specific style
# apply_visual_style("dark_neon")
# Out:
# ✅ Applied random style: 'vibrant_tech' with colors ['#00B8A9', '#F6416C', '#FFDE7D', '#6A2C70', '#355C7D']

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.visual_style import randomize_palette, apply_visual_style
randomize_palette()
# Out:
# ✅ src package loaded successfully.
# ✅ Applied random style: 'dark_neon' with colors ['#00F5D4', '#9B5DE5', '#F15BB5', '#FEE440', '#00BBF9']
